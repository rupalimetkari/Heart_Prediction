# %% [markdown]
# <FONT SIZE=6, COLOR="Dark BLUE"><B><U><Center>CAPSTONE PROJECT</U></B></FONT><BR>

# %% [markdown]
# <FONT SIZE=4, COLOR="Blue"><B><U>TITLE:</U></B>  <BR>Heart Failure Clinical Prediction</FONT>
# <BR>
# <P>
# <B>Class name:</B> ALY6140- Analytics Systems Technology- <B>Group 5</B>
# <BR>
# <B>Instructor's name:</B> Prof. Varsha Kulkarni
# <BR>
# <B>Date of submission:</B> 04/06/2021
# <BR>
# <B>Submitted By:</B><ul><li>Urvashi Sharma<BR><li> Mayank Kumar Pandey<BR><li> Rupali Metkari</ul>
# <BR>
# <P>
#
# <FONT SIZE=4, COLOR="BLUE"><B><U>CONTRIBUTION IN PROJECT:</U></B></FONT>
# <BR> <BR>
#
# <B><U>Urvashi Sharma:</B></U><BR>
# <ul>
# <li>Analyzed the data for the initial data pre-processing and understand it for the analysis. </li>
# <li>Exploratory Data Analysis of the Heart failure clinical dataset</li>
# <li>Data Cleaning, data Visualization using the libraries seaborn and matplotlib to plot the graphs for the analysis. </li>
# <li>Analyzing the correlation matrix for the data exploration and defined the variables for the data analysis. </li>
# <li>Analyzing the regression models with the confusion matrix. </li>
# <li>Prepared the R Markdown report with all the detailed explanation with observation and conclusion.  </li>
# <li>Helped in preparing the presentation with all the explanation.  </li>
# </ul>
#
# <B><U>Mayank Kumar Pandey</U></B><BR>
# <ul>
# <li>Defined target variables and feature variables.</li>
# <li>Plotted correlation matrix and identify multicollinearity if any. </li>
# <li>Build Classification model using Random Forest Classification and Logistic regression </li>
# <li>Model comparison and recommendation: designed programs to compare model performance and then recommend which model is suitable for further use. </li>
# <li>Data Cleaning, Data wrangling, data visualization using python libraries like seaborn, matplotlib. </li>
#  <li>Imputation of missing value using suitable imputation values as per nature of the column e.g., Categorical columns, numerical column etc. </li>
# <li>Did Feature engineering for identifying columns out of 13 columns that can be used for predictive modeling and data visualization. </li>
# </ul>
#
# <B><U>Rupali Metkari:</B></U><BR>
# <ul>
# <li>Created a descriptive report of multiple graphs in the code.</li>
# <li>Analysed the initial dataset, and contributed to cleaning the dataset and filling the missing values</li>
# <li>Identified highly and leasted correlated variables by developing the correlation matrix of the dataset</li>
# <li>Actively contributed to making the presentation of the Final Project.</li>
# <li>Helped in writing of Report for the project.</li>
# </ul>
#
# <BR>
# <FONT SIZE=4, COLOR="BLUE"><B><U>INTRODUCTION</U></B></FONT>
# <BR>
# <P>
# Python programming language is the best choice for building data analytics tools. Python can easily provide better knowledge, get examples, and correlate data from big datasets. Python is additionally significant in self-service analytics. <BR>
# We are using heart failure dataset. We use python for data analysis and machine learning algorithm. We predict whether a particular person has a heart disease or not based on the attributes of dataset and find various insights from this dataset which could help in predicting the reasons of a heart disease which could led to death.
# This is multivariate type of dataset which means providing or involving a variety of separate mathematical or statistical variables and data analysis.<BR>
# <P><B><U>Business Problem Description:</U></B>
#
# Predict the survival of each patient having heart failure symptoms and to detect the most important clinical features (or risk factors) that may lead to heart failure. By applying exploratory data analysis on the heart failure clinical records dataset, below are the questions that needs to be considered: <BR><BR>
#     Q1. What are the correlations between the different variables of the dataset?<BR>
#     Q2. What is the number of deaths due to heart failure vs survival of the patient?<BR>
#     Q3. What is the death events of the patients based on Age and sex?<BR>
#     Q4. What is the impact of diabetes on the heart failure of the patients?<BR>
#     Q5. What is the impact of smoking on the heart failure of the patients?<BR>
#     Q6. What are the Age groups affected the most by the heart failure?<BR>
#
# <U>Steps which we followed are as follows:</U><ol>
# <li>Install libraries: We pandas and numpy for basic evaluation of data.  We used matplotlib and seaborn for plotting graph which helped in better understanding of the data. Finally, we used sklearn for creating the model.</li>
# <li>Import Dataset- Here we imported heart_failure_clinical_records.csv. </li>
# <li>Clean Data - This dataset having 299 rows and 13 variables. We checked for null/missing or inappropriate values in the dataset. </li>
# <li>Creating Correlation Matrix: Correlation indicates how the features are related to each other or to the target variable. Heatmap makes it easy to classify the features are most relevant to the target variable. We plotted the correlation matrix of the dataset and later found out that time and age attribute were highly correlated to death event. </li>
# <li>Data Visualization: Used seaborn library to create multiple graphs and plot of the dataset which helped us to understand the dataset and draw preliminary conclusions. </li>
# <li>Data Analysis: We finally used sklearn to create a model of the dataset. We used logistic regression and Random Forest to create the model.<ul>
# <li>Gathered columns.</li>
# <li>Splitting Dataset into train and test data. </li>
# <li>Creating the model using logistic regression. </li>
# <li>Prediction using the model. </li>
# <li>Model Evaluation using Random Forest algorithm.</li></ul></li></ol>

# %% [markdown]
# <BR>
# <FONT SIZE=4, COLOR="BLUE"><B><U><Left>ANALYSIS</U></B></FONT>
# <BR>
# <P>
#     Below are the analysis of the dataset related to heart failure clinical records:<BR>

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, plot_confusion_matrix, plot_roc_curve
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# <BR><B><U>Importing publicly available dataset for heart fail record</B></U>

# %%
# Importing the publicaly available dataset for heart fail record
url1 = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00519/heart_failure_clinical_records_dataset.csv' 
dataset = pd.read_csv(url1, error_bad_lines=False)

# %% [markdown]
# <BR><B><U>Data Cleaning:</B></U>

# %%
# Data Cleaning
missing = dataset.isna().sum().sort_values(ascending = False)
percent_missing = ((missing / dataset.isnull().count()) * 100).sort_values(ascending = False)
missing_df = pd.concat([missing,percent_missing], axis = 1, keys = ['Total', 'Percent'],sort = False)
missing_df[missing_df['Total'] >= 1]
# Out:
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %%
# Dataset after data cleaning
dataset
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# <BR><B><U>Correlation Matrix</B></U><BR><BR>
#     <B>Q1. What are the correlations between the different variables of the dataset?</B>

# %%
# Correlation Matrix
corrMatrix= dataset.corr()

fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches

sns.heatmap(corrMatrix, annot=True,linewidth=0.8)
plt.title("Fig. 1: Correlation Matrix for the different variables", size=16)
plt.show()

## There is no sign of multicollinearity

# %% [markdown]
# <U><B>Observations: </B></U>
# <li>There are no signs of multicollinearity among features
# <li> Age, Time for  follow up and serum creatinine has highest correlation with target feature DEATH_EVENT
#
#  </li>
#
# <BR>

# %% [markdown]
#   <BR><B>Q2. What is the number of deaths due to heart failure vs survival of the patient?</B>

# %%
sns.countplot(dataset['DEATH_EVENT'])

dataset['DEATH_EVENT'].value_counts(normalize=True)

plt.title("Fig2: Barplot of Death counts", size=14)
plt.xlabel("Death Events", size=12)
plt.ylabel("Counts", size=12)
### Dataset is not highly imbalanced
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Counts')

# %% [markdown]
# <U><B>Observations: </B></U><BR><ul>
#     <li>
#     As shown in fig2, the number of death counts(95) is less than the survival count(210) of the patients.
#     </li>
#     <li>
#     We can interpret that the there are more survival rate of the patients as compared to the death rate.
#     </li>
#     </ul>

# %% [markdown]
# <BR><B>Q3. What is the death events of the patients based on Age and sex?</B>

# %%
sns.catplot(x="sex", y="age", hue="DEATH_EVENT", kind="bar", data=dataset) 
plt.title("Fig3: Grouped barplot of Death with different ages and sex", size=14)
plt.xlabel("Sex", size=12)
plt.ylabel("Age", size=12)
# death event due to heart fail is reltively low in  women
# Out:
# Text(13.546458333333334, 0.5, 'Age')

# %% [markdown]
# <U><B>Observations: </B></U><BR><ul>
#     <li>
#     As shown in fig3, there are higher deaths in male(Sex= 1) patients as compared to the female patients above 6o years of age. While survival rate of the both the sexes patients are approximately same.
#     </li>
#     </ul>

# %% [markdown]
#   <BR><B>Q4. What is the impact of diabetes on the heart failure of the patients?</B>

# %%
sns.catplot(x="diabetes", hue="DEATH_EVENT", kind="count", data=dataset)
plt.title("Fig4: Grouped barplot of Death counts for diabetes patients", size=14)
plt.xlabel("Diabetes", size=12)
plt.ylabel("Counts", size=12)
 ## diabetic patients tends to live lesser than normal person
# Out:
# Text(14.95427083333334, 0.5, 'Counts')

# %% [markdown]
# <U><B>Observations: </B></U><BR><ul>
#     <li>
#     As shown in fig4, the survival rate of the non-diabetic patients(118) are higher than the diabetic patients(85). While death count of the non-diabetic patients are more than the daibetic patients who died from heart fail.
#     </li>
#     <li>
#     So, we can not say that diabetic patients have higher death count due to heart fail.
#     </li>
#     </ul>

# %% [markdown]
#   <BR><B>    Q5. What is the impact of smoking on the heart failure of the patients?</B>

# %%
sns.catplot(x="smoking", hue="DEATH_EVENT", kind="count", data=dataset)
dataset['smoking'].value_counts(normalize=True)
plt.title("Fig5: Grouped barplot of Death counts for smokers", size=14)
plt.xlabel("Smoking", size=12)
plt.ylabel("Counts", size=12)
 ## somker tends to live lesser than non-smoker
# Out:
# Text(14.95427083333334, 0.5, 'Counts')

# %% [markdown]
# <U><B>Observations: </B></U><BR><ul>
#     <li>
#     As shown in fig5, the survival count of the patients(138) who does not smokes are higher than the patients who smokes(65). While death count of the patients(65) who does not smokes are more than the patients who smokes and died from heart fail.
#     </li>
#     <li>
#     So, we can say that death rate of the patients does not depend upon smoking.
#     </li>
#     </ul>

# %% [markdown]
#   <BR><B>    Q6. What are the Age groups affected the most by the heart failure?</B>

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(
    dataset['age'], norm_hist=False, kde=False, bins=20, hist_kws={"alpha": 1}
).set(xlabel='age', ylabel='Count');
plt.title("Fig6: Barplot of different Age counts", size=14)
plt.xlabel("Age", size=12)
plt.ylabel("Counts", size=12)
## age distribution of dataset is normal and above 40
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Counts')

# %% [markdown]
# <U><B>Observations: </B></U><BR><ul>
#     <li>
#     As shown in fig6, the peopleof age 60 years have highest heart failure count as compared to others. While death count of the patients having age from 87 to 90 years hasve the lowest heart failure rate and died from heart failure.
#     </li>
#     <li>
#     Patients with age 50, 60, 70 years are having high heart failure than others
#     </li>
#     </ul>

# %% [markdown]
# <BR><B><U>Predictive Analysis</B></U>
# <BR>Dividing Dataset into target and feature column

# %%
X = dataset.loc[:,dataset.columns!='DEATH_EVENT']
Y = dataset['DEATH_EVENT']

# %% [markdown]
# Splitting Dataset into train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 786,stratify= Y) ### using stratified train test split to avoid distribution shift in test data
X_test
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 231  70.0        0                        93         0                 35
# 190  80.0        0                       582         1                 35
# 129  53.0        1                       270         1                 35
# 43   72.0        0                       127         1                 50
# 96   63.0        1                       514         1                 25
# 155  60.0        1                       231         1                 25
# 136  65.0        1                        59         1                 60
# 68   70.0        0                       161         0                 25
# 71   58.0        0                       582         1                 35
# 166  53.0        0                       196         0                 60
# 263  68.0        1                       157         1                 60
# 217  54.0        1                       427         0                 70
# ...

# %% [markdown]
# Defining a reusable function to evaluate model performance

# %%
## defining a reusable function to evaluate model performance

def eval_result(model_name,y_train,y_predtrain,y_test,y_predtest):
    """
    :param model_name: 
    :param y_train: 
    :param y_predtrain: 
    :param y_test: 
    :param y_predtest: 
    :output: 
    """
    

    train_accuracy = accuracy_score(y_train, y_predtrain)
    print(f'training data accuracy {train_accuracy}')
 
    
    test_accuracy = accuracy_score(y_test, y_predtest)
    print(f'testing data accuracy {test_accuracy}')
   
    
    print(classification_report(y_test,y_predtest,digits=5))
    
    plot_confusion_matrix(model_name, X_test, y_test,cmap=plt.cm.pink, normalize = 'all')
    plt.title("Confusion Matrix", size =14)
    plot_roc_curve(model_name, X_test, y_test)
    plt.title("ROC CURVE", size =14)

# %% [markdown]
# <B>Model Building using logistic regression</B>

# %%
model_lr = LogisticRegression()

model_lr.fit(X_train,y_train)
y_predtest_lr = model_lr.predict(X_test)
y_predtrain_lr = model_lr.predict(X_train)

pr1=pd.DataFrame(y_predtest_lr,columns=["Pred"])

pr1["Actual"]=y_test.values

print(f"{pr1}")

eval_result(model_lr,y_train,y_predtrain_lr,y_test,y_predtest_lr)
# Out:
#     Pred  Actual
# 0      0       0
# 1      0       0
# 2      0       0
# 3      1       0
# 4      1       0
# 5      0       0
# 6      0       0
# 7      1       1
# 8      1       0
# 9      0       0
# 10     0       0
# 11     0       1
# 12     0       0
# 13     1       1
# 14     1       1
# 15     0       0
# 16     1       1
# 17     0       0
# 18     0       0
# 19     0       0
# 20     0       0
# 21     0       0
# 22     1       1
# 23     0       0
# 24     0       1
# 25     0       0
# 26     0       0
# 27     0       0
# 28     0       0
# 29     0       0
# 30     0       1
# 31     0       0
# 32     0       0
# 33     0       0
# 34     0       0
# 35     0       0
# 36     1       0
# 37     1       1
# 38     0       1
# 39     0       0
# 40     1       1
# 41     0       0
# 42     1       1
# 43     0       0
# 44     1       1
# 45     0       0
# 46     1       1
# 47     1       0
# 48     0       0
# 49     0       0
# 50     1       1
# ...

# %%
# get importance
importance_lr = model_lr.coef_

pr2=pd.DataFrame(importance_lr.T)#,columns=["Imp"]
pr2
pr2["Feature"]=X_test.columns
pr2
#print(f"{pr2}")
# Out:
#            0                   Feature
# 0   0.053525                       age
# 1  -0.000368                   anaemia
# 2   0.000312  creatinine_phosphokinase
# 3   0.000597                  diabetes
# 4  -0.075838         ejection_fraction
# 5  -0.000359       high_blood_pressure
# 6  -0.000002                 platelets
# 7   0.004541          serum_creatinine
# 8   0.010382              serum_sodium
# 9  -0.000043                       sex
# 10 -0.000359                   smoking
# 11 -0.021017                      time

# %% [markdown]
# Model Building using Random Forest algorithm

# %% [markdown]
# Hyperparameter Tuning

# %%
''''
## run once
# Hyperparameter Tuning
from sklearn.ensemble import RandomForestClassifier


n_estimators_hyp = [100,200,300,400,500,700,1000]
min_sample_leaf_hyp = np.linspace(1,20, 20);

oobscore_list=dict()

for i in n_estimators_hyp:
    for j in min_sample_leaf_hyp:
        rf_model = RandomForestClassifier(n_estimators=i, min_samples_leaf=int(j), oob_score=True);
        rf_model.fit(X_train, y_train)
        key = "n_estimator =" +str(i)+" min_sample_leaf ="+str(j);
        oobscore_list[key]=rf_model.oob_score_

    #oobscore_list.append(rf_model.oob_score_)

oobscore_list
'''''''''''
# Out:
# '\'\n## run once\n# Hyperparameter Tuning\nfrom sklearn.ensemble import RandomForestClassifier\n\n\nn_estimators_hyp = [100,200,300,400,500,700,1000]\nmin_sample_leaf_hyp = np.linspace(1,20, 20);\n\noobscore_list=dict()\n\nfor i in n_estimators_hyp:\n    for j in min_sample_leaf_hyp:\n        rf_model = RandomForestClassifier(n_estimators=i, min_samples_leaf=int(j), oob_score=True);\n        rf_model.fit(X_train, y_train)\n        key = "n_estimator =" +str(i)+" min_sample_leaf ="+str(j);\n        oobscore_list[key]=rf_model.oob_score_\n\n    #oobscore_list.append(rf_model.oob_score_)\n\noobscore_list\n'

# %%
from sklearn.ensemble import RandomForestClassifier

# building model from parameters choosen from hyperparameter tuning

rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=400,
                             min_samples_split=10,
                             min_samples_leaf=1,
                             max_features='auto',
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1)
rf.fit(X_train, y_train)
print("%.4f" % rf.oob_score_)
# Out:
# 0.8536

# %% [markdown]
# Predicting Results

# %%
# Predicting results
y_predtrain = rf.predict(X_train)
y_predtest = rf.predict(X_test)

pr1=pd.DataFrame(y_predtest,columns=["Pred"])

pr1["Actual"]=y_test.values

print(f"{pr1}")
# Out:
#     Pred  Actual
# 0      0       0
# 1      1       0
# 2      0       0
# 3      1       0
# 4      0       0
# 5      0       0
# 6      0       0
# 7      1       1
# 8      0       0
# 9      0       0
# 10     0       0
# 11     0       1
# 12     0       0
# 13     0       1
# 14     1       1
# 15     0       0
# 16     1       1
# 17     0       0
# 18     0       0
# 19     0       0
# 20     0       0
# 21     0       0
# 22     1       1
# 23     1       0
# 24     0       1
# 25     0       0
# 26     0       0
# 27     0       0
# 28     0       0
# 29     0       0
# 30     0       1
# 31     0       0
# 32     0       0
# 33     0       0
# 34     0       0
# 35     0       0
# 36     0       0
# 37     0       1
# 38     0       1
# 39     0       0
# 40     1       1
# 41     0       0
# 42     0       1
# 43     0       0
# 44     1       1
# 45     0       0
# 46     1       1
# 47     0       0
# 48     0       0
# 49     0       0
# 50     1       1
# ...

# %%
## evaluating model performance 
eval_result(rf,y_train,y_predtrain,y_test,y_predtest)
# Out:
# training data accuracy 0.9539748953974896
# testing data accuracy 0.8333333333333334
#               precision    recall  f1-score   support
#
#            0    0.84444   0.92683   0.88372        41
#            1    0.80000   0.63158   0.70588        19
#
#     accuracy                        0.83333        60
#    macro avg    0.82222   0.77920   0.79480        60
# weighted avg    0.83037   0.83333   0.82741        60

# %%
# get importance of feature
importance_rf = rf.feature_importances_

pr2=pd.DataFrame(importance_rf,columns=["Imp"])

pr2["Feature"]=X_test.columns

print(f"{pr2}")
# Out:
#          Imp                   Feature
# 0   0.098813                       age
# 1   0.006192                   anaemia
# 2   0.065722  creatinine_phosphokinase
# 3   0.005197                  diabetes
# 4   0.128223         ejection_fraction
# 5   0.005440       high_blood_pressure
# 6   0.065492                 platelets
# 7   0.129314          serum_creatinine
# 8   0.053676              serum_sodium
# 9   0.006133                       sex
# 10  0.005286                   smoking
# 11  0.430510                      time

# %% [markdown]
# <U><B>Observations: </B></U><BR><ul>
#     <li> time,ejection_fraction and serum_creatinine are most important feature
#     <li> training accuracy is 95%  and testing accuracy is 83% which seems ok and there is no sign of overfitting
#    <li> Area under curve is 91%
#     </ul>

# %% [markdown]
# <BR>
# <FONT SIZE=4, COLOR="BLUE"><B><U><Left>CONCLUSION</U></B></FONT><BR><BR>
#     We can infer the below conclusions from the data analysis:
# <BR>
#     <ul>
#     <li> Most important feature is serum_creatinine and ejection_fraction after time.</li>
#         <li>From fig 2, we can infer that the survival count is more than the death count due to heart fail.
#          </li>
#         <li>From fig 3, we can conclude that there are higher number of deaths in male patients as compared to the female patients above 6o years of age. While survival rate of the both the sexes patients are approximately same.
#      <li>
#          We can infer from the above observations of fig 4, 5 that smoking and diabetes does not affect the heart fail of the patients. As patients having diabetes and who smokes survived from the heart attack most than the death.
#          </li>
#         <li>
#          We can observe from the fig 6 that patients with ages 50, 60, 70 years are having high heart failure than others and patients with tha age 87 to 90 years have the minimum heart rate failure.
#          </li>
#     <li>Based on the model prediction and feature importance we can say that doctors may focus on seerum_creatinine and ejection fraction</li>
#      <li>Time is also one of the most important feature. This shows timely medical help and enough observaion period may help to reduce death caused by heart failure
#         </li>
#     </ul>
# <P>

# %% [markdown]
# <BR>
# <FONT SIZE=4, COLOR="BLUE"><B><U><Left>REFERENCES</U></B></FONT>
# <BR><ul>
#     <li>Heart failure clinical records Dataset. Index of /ml/machine-learning-databases/00519. Retrieved from <a>http://archive.ics.uci.edu/ml/machine-learning-databases/00519/</a></li>
# <li>Davide Chicco(2020). Machine learning can predict survival of patients with heart failure from serum creatinine and ejection fraction alone. Retrieved on Feb 03, 2020 from <a>https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-020-1023-5#Sec14</a></li>
# <li>Better Heatmaps and Correlation Matrix Plots in Python(Drazen Zaric 15 Apr, 2019) Towards data science: <a>https://towardsdatascience.com/better-heatmaps-and-correlation-matrix-plots-in-python-41445d0f2bec </a></li>
# <li>Learning Model Building in Scikit-learn(6 Aug, 2019) Geeksforgeeks: <a>https://www.geeksforgeeks.org/learning-model-building-scikit-learn-python-machine-learning-library/</a></li>
# <li>Heart Disease UCI-Diagnosis & Prediction, Hardik Deshmukh(18 Jun,2020) towards data science: <a>https://towardsdatascience.com/heart-disease-uci-diagnosis-prediction-b1943ee835a7#a3db  </a></li>
#
# </ul>
#
# <P>

# %% [markdown]
# <BR>
# <FONT SIZE=4, COLOR="BLUE"><B><U><Left>APPENDIX</U></B></FONT>
# <BR>
# <P>

# %% [markdown]
# Please see attached ALY6140_Capstone_Project_Group5.ipynb file
